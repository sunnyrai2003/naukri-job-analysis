# %% [markdown]
# # Real Time Project Using Python or Python-Librarie's
# # (A part Big Data Analysis)
# # The Naukri DataSet

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/jobs.csv')

# %%
df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 74696  6.012391e+10                            Data Science Specialist
# 74697  6.012301e+10                                  Solution Designer
# 74698  6.012301e+10  Hiring-Java-Pune/Mumbai/Bangalore/Hyderabad/Ch...
# 74699  6.012301e+10  Unified Functional Testing/UFT Automation Testing
# 74700  6.012301e+10                 Senior Product Experience Engineer
#
#              company experience         salary  \
# 0          Hdfc Bank    1-6 Yrs  Not disclosed
# ...

# %%
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %%
df.tail()
# Out:
#              job_id                                           job_role  \
# 74696  6.012391e+10                            Data Science Specialist
# 74697  6.012301e+10                                  Solution Designer
# 74698  6.012301e+10  Hiring-Java-Pune/Mumbai/Bangalore/Hyderabad/Ch...
# 74699  6.012301e+10  Unified Functional Testing/UFT Automation Testing
# 74700  6.012301e+10                 Senior Product Experience Engineer
#
#              company experience         salary  \
# 74696      Accenture    2-4 Yrs  Not disclosed
# 74697  Tech Mahindra    4-9 Yrs  Not disclosed
# 74698     Citiustech    3-8 Yrs  Not disclosed
# 74699      Capgemini    5-9 Yrs  Not disclosed
# 74700        Red Hat   7-12 Yrs  Not disclosed
#
#                                                 location  rating  \
# 74696  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 74697  Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...     3.7
# ...

# %%
df.shape
# Out:
# (74701, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74701 entries, 0 to 74700
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           74541 non-null  float64
#  1   job_role         74541 non-null  object
#  2   company          74540 non-null  object
#  3   experience       73272 non-null  object
#  4   salary           74541 non-null  object
#  5   location         73315 non-null  object
#  6   rating           38822 non-null  float64
#  7   reviews          38822 non-null  object
#  8   resposibilities  74521 non-null  object
#  9   posted_on        74541 non-null  object
#  10  job_link         74541 non-null  object
#  11  company_link     74541 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 6.8+ MB

# %%
df.columns
# Out:
# Index(['job_id', 'job_role', 'company', 'experience', 'salary', 'location',
#        'rating', 'reviews', 'resposibilities', 'posted_on', 'job_link',
#        'company_link'],
#       dtype='object')

# %%
df.dtypes
# Out:
# job_id             float64
# job_role            object
# company             object
# experience          object
# salary              object
# location            object
# rating             float64
# reviews             object
# resposibilities     object
# posted_on           object
# job_link            object
# company_link        object
# dtype: object

# %%
df.isna().sum()
# Out:
# job_id               160
# job_role             160
# company              161
# experience          1429
# salary               160
# location            1386
# rating             35879
# reviews            35879
# resposibilities      180
# posted_on            160
# job_link             160
# company_link         160
# dtype: int64

# %% [markdown]
# Now firstly object type concvert str type

# %%
for col in df.columns:
  if df[col].dtype=='object':
    df[col]=df[col].str.lower()

# %%
df.columns
# Out:
# Index(['job_id', 'job_role', 'company', 'experience', 'salary', 'location',
#        'rating', 'reviews', 'resposibilities', 'posted_on', 'job_link',
#        'company_link'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 1354

# %%
df.drop_duplicates(inplace=True)

# %%
duplicates=df['job_id'].duplicated(keep=False)

# %%
duplicates.sum()
# Out:
# 673

# %% [markdown]
# **The line of code effectively cleans the DataFrame by removing duplicate rows and ensures that the index is sequential and starts from 0, making it easier to work with the DataFrame in subsequent operations.**

# %%
df.drop_duplicates()
df=df.drop_duplicates().reset_index(drop=True)

# %%
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      branch banking - calling for women candidates  hdfc bank
# 1  6.012391e+10                       product owner senior manager  accenture
# 2  6.012391e+10  employee relations and policies associate manager  accenture
# 3  6.012391e+10         employee relations and policies specialist  accenture
# 4  6.012301e+10                                  sap bo consultant   mindtree
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
# 2    3-7 yrs  not disclosed
# 3    3-7 yrs  not disclosed
# 4    5-7 yrs  not disclosed
#
#                                             location  rating        reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110 reviews
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
# 2  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
# ...

# %%
for i in df.columns:
  print(f'Colums Name: {i}')
  print(f'Data Type: {df[i].dtypes}')
  print(f'Unique Values: {df[i].unique()}')
  print(f'Number of unique value in column: {df[i].nunique()}')
  print(f'Number of value count: {df[i].value_counts()}')
  print('\n')
# Out:
# Colums Name: job_id
# Data Type: float64
# Unique Values: [7.01230061e+10 6.01239059e+10 6.01239059e+10 ... 2.31222004e+11
#  1.71220001e+11 7.10220087e+10]
# Number of unique value in column: 73009
# Number of value count: job_id
# 6.012301e+10    3
# 7.012301e+10    2
# 5.012301e+10    2
# 5.012301e+10    2
# 5.012301e+10    2
#                ..
# 2.912225e+11    1
# 2.912225e+11    1
# 2.912225e+11    1
# 2.912225e+11    1
# 7.102201e+10    1
# Name: count, Length: 73009, dtype: int64
#
#
# Colums Name: job_role
# Data Type: object
# Unique Values: ['branch banking - calling for women candidates'
#  'product owner senior manager'
#  'employee relations and policies associate manager' ...
#  'hiring for international voice process | gurgaon | 35k'
#  'fresher engineer' 'anatomy trainer - part time / full time']
# Number of unique value in column: 50340
# Number of value count: job_role
# business development executive                  311
# ...

# %%
df.head(3)
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      branch banking - calling for women candidates  hdfc bank
# 1  6.012391e+10                       product owner senior manager  accenture
# 2  6.012391e+10  employee relations and policies associate manager  accenture
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
# 2    3-7 yrs  not disclosed
#
#                                             location  rating        reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110 reviews
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
# 2  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
#
#                                      resposibilities  posted_on  \
# 0     customer service,sales,relationship management  1 day ago
# 1  product management,market analysis,change mana...  1 day ago
# ...

# %%
df.shape
# Out:
# (73347, 12)

# %% [markdown]
# # Cleaning Part

# %%
df[df['job_id'].isnull()]
# Out:
#        job_id job_role company experience salary location  rating reviews  \
# 41723     NaN      NaN     NaN        NaN    NaN      NaN     NaN     NaN
#
#       resposibilities posted_on job_link company_link
# 41723             NaN       NaN      NaN          NaN

# %%
df.dropna(subset=['job_id'], inplace=True)

# %%
df['job_id'] = df['job_id'].astype(int)

# %%
df.head()
# Out:
#         job_id                                           job_role    company  \
# 0  70123006070      branch banking - calling for women candidates  hdfc bank
# 1  60123905908                       product owner senior manager  accenture
# 2  60123905898  employee relations and policies associate manager  accenture
# 3  60123905897         employee relations and policies specialist  accenture
# 4  60123008332                                  sap bo consultant   mindtree
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
# 2    3-7 yrs  not disclosed
# 3    3-7 yrs  not disclosed
# 4    5-7 yrs  not disclosed
#
#                                             location  rating        reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110 reviews
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
# 2  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
# ...

# %%
df1=df['job_id'].duplicated().sum()

# %%
df1
# Out:
# 337

# %%
df_cleaned=df.drop_duplicates(subset='job_id',inplace=True)

# %%
df_cleaned

# %%
df.head(2)
# Out:
#         job_id                                       job_role    company  \
# 0  70123006070  branch banking - calling for women candidates  hdfc bank
# 1  60123905908                   product owner senior manager  accenture
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
#
#                                             location  rating        reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110 reviews
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
#
#                                      resposibilities  posted_on  \
# 0     customer service,sales,relationship management  1 day ago
# 1  product management,market analysis,change mana...  1 day ago
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
#                                         company_link
# ...

# %%
df.dtypes
# Out:
# job_id               int64
# job_role            object
# company             object
# experience          object
# salary              object
# location            object
# rating             float64
# reviews             object
# resposibilities     object
# posted_on           object
# job_link            object
# company_link        object
# dtype: object

# %% [markdown]
# # Experience section

# %%
# create two new colum min_experience or max_experience
df[['min_experience','max_experience']]=df['experience'].str.split('-',expand=True)

# %%
# df[df['experience'].isna()]

# %%
# Remove 'yrs' and convert to numeric, handling errors
df['min_experience'] = pd.to_numeric(df['min_experience'].str.replace('yrs', '').str.strip(), errors='coerce')
df['max_experience'] = pd.to_numeric(df['max_experience'].str.replace('yrs', '').str.strip(), errors='coerce')

# %%
# Convert to nullable integer type to handle NaN values
df['min_experience'] = df['min_experience'].astype('Int64')
df['max_experience'] = df['max_experience'].astype('Int64')

# %%
df.head(2)
# Out:
#         job_id                                       job_role    company  \
# 0  70123006070  branch banking - calling for women candidates  hdfc bank
# 1  60123905908                   product owner senior manager  accenture
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
#
#                                             location  rating        reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110 reviews
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129 reviews
#
#                                      resposibilities  posted_on  \
# 0     customer service,sales,relationship management  1 day ago
# 1  product management,market analysis,change mana...  1 day ago
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
# ...

# %% [markdown]
# # Rating Section

# %%
df['rating'].isna().sum()
# Out:
# 35405

# %% [markdown]
# # Total 35405 Nan Vlaue in a rating columns so, is the best thing nan replace '0'

# %%
df['rating'].fillna(0,inplace=True)
# Out:
# <ipython-input-82-16691237f9af>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(0,inplace=True)

# %%
df['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# # reviews section

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73009 entries, 0 to 73327
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           73009 non-null  int64
#  1   job_role         73009 non-null  object
#  2   company          73008 non-null  object
#  3   experience       71758 non-null  object
#  4   salary           73009 non-null  object
#  5   location         71801 non-null  object
#  6   rating           73009 non-null  float64
#  7   reviews          37604 non-null  object
#  8   resposibilities  72989 non-null  object
#  9   posted_on        73009 non-null  object
#  10  job_link         73009 non-null  object
#  11  company_link     73009 non-null  object
#  12  min_experience   71758 non-null  Int64
#  13  max_experience   71758 non-null  Int64
# dtypes: Int64(2), float64(1), int64(1), object(10)
# memory usage: 8.5+ MB

# %%
# df[df['reviews'].isna()]

# %%
df['reviews']=df['reviews'].fillna(0).str.replace('reviews','').astype(float)

# %%
df.head()
# Out:
#         job_id                                           job_role    company  \
# 0  70123006070      branch banking - calling for women candidates  hdfc bank
# 1  60123905908                       product owner senior manager  accenture
# 2  60123905898  employee relations and policies associate manager  accenture
# 3  60123905897         employee relations and policies specialist  accenture
# 4  60123008332                                  sap bo consultant   mindtree
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
# 2    3-7 yrs  not disclosed
# 3    3-7 yrs  not disclosed
# 4    5-7 yrs  not disclosed
#
#                                             location  rating  reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110.0
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
# 2  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
# ...

# %% [markdown]
# # Salary section

# %%
df['salary'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73323    False
# 73324    False
# 73325    False
# 73326    False
# 73327    False
# Name: salary, Length: 73009, dtype: bool

# %%
df['salary'].nunique()
# Out:
# 813

# %%
import numpy as np

# %%
# Function to extract min and max salary
def extract_salary_range(salary):
    salary = salary.strip()

    if salary.upper() == 'not disclosed':
        return pd.Series([np.nan, np.nan])  # Return NaN for both min and max

    # Check for specific salary format with variable
    if '(' in salary:
        # Extract the numeric part before the parentheses
        salary = salary.split('(')[0].strip()

    # Check for salary range
    if ' - ' in salary:
        # Remove ' pa.' if present and split the range
        salary = salary.replace(' pa.', '').strip()
        min_salary, max_salary = salary.split(' - ')

        # Remove commas and check if they are numeric
        min_salary_cleaned = min_salary.replace(',', '').strip()
        max_salary_cleaned = max_salary.replace(',', '').strip()

        if min_salary_cleaned.isdigit() and max_salary_cleaned.isdigit():
            min_salary = int(min_salary_cleaned)
            max_salary = int(max_salary_cleaned)
            return pd.Series([min_salary, max_salary])
        else:
            return pd.Series([np.nan, np.nan])  # Return NaN if not valid

    # If it's a single salary value
    salary_cleaned = salary.replace(',', '').strip()
    if salary_cleaned.isdigit():
        min_salary = int(salary_cleaned)
        return pd.Series([min_salary, min_salary])  # Same value for min and max
    else:
        return pd.Series([np.nan, np.nan])  # Return NaN if not valid

# Apply the function to the salary column
df[['min_salary', 'max_salary']] = df['salary'].apply(extract_salary_range)

# %%
df.head()
# Out:
#         job_id                                           job_role    company  \
# 0  70123006070      branch banking - calling for women candidates  hdfc bank
# 1  60123905908                       product owner senior manager  accenture
# 2  60123905898  employee relations and policies associate manager  accenture
# 3  60123905897         employee relations and policies specialist  accenture
# 4  60123008332                                  sap bo consultant   mindtree
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
# 2    3-7 yrs  not disclosed
# 3    3-7 yrs  not disclosed
# 4    5-7 yrs  not disclosed
#
#                                             location  rating  reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110.0
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
# 2  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
# ...

# %%
df.columns
# Out:
# Index(['job_id', 'job_role', 'company', 'experience', 'salary', 'location',
#        'rating', 'reviews', 'resposibilities', 'posted_on', 'job_link',
#        'company_link', 'min_experience', 'max_experience', 'min_salary',
#        'max_salary'],
#       dtype='object')

# %%
df.columns.nunique()
# Out:
# 16

# %% [markdown]
# # Calculate basic statistics

# %%
# mean value of min_salary.
np.mean(df['min_salary'])
# Out:
# 572843.1958244246

# %%
# mean value of max_salary.
np.mean(df['max_salary'])
# Out:
# 918938.8127279588

# %%
# mean std of min_salary.
np.std(df['min_salary'])
# Out:
# 1459537.4819895488

# %%
# mean std of ma_salary.
np.std(df['max_salary'])
# Out:
# 1967509.1076209329

# %%
# min experience.
np.min(df['max_experience'])
# Out:
# 0

# %%
# max experience.
np.max(df['max_experience'])
# Out:
# 31

# %% [markdown]
# # Find Company Insights
# # Insights into how company reputation influences job seeker behavior and preferences.

# %%
# now check salary is grater then 100000
df['Salary_Category']=np.where(df['max_salary']>100000, 'High','low')

# %%
# df.head()

# %% [markdown]
# #1. Calculate the average rating for each company.

# %%
avg_rating=df.groupby('company')['rating'].mean()

# %%
avg_rating.head()
# Out:
# company
# (v)wecare technology                         2.6
# .                                            3.5
# 0xblock  0xblock                             0.0
# 102/108 ambulance services, uttar pradesh    3.8
# 10xgrowth                                    0.0
# Name: rating, dtype: float64

# %% [markdown]
# #2. Identify companies with the highest and lowest average ratings.

# %%
# Identify the company with the highest average rating
highest_rating_company= avg_rating.loc[avg_rating.idxmax()]
highest_rating_company
# Out:
# 5.0

# %%
# # Identify the company with the Lowest average rating
lowest_rating_company=avg_rating.loc[avg_rating.idxmin()]
lowest_rating_company
# Out:
# 0.0

# %% [markdown]
# #3. Calculate the total number of reviews for each company.

# %%
Number_of_reviews=df.groupby('company')['reviews'].sum()
Number_of_reviews.head(10)
# Out:
# company
# (v)wecare technology                          125.0
# .                                              14.0
# 0xblock  0xblock                                0.0
# 102/108 ambulance services, uttar pradesh    1151.0
# 10xgrowth                                       0.0
# 13squad consulting services (opc)               0.0
# 18 steps consultants                            0.0
# 18th digitech                                   2.0
# 1mg                                          2497.0
# 1point1                                      3200.0
# Name: reviews, dtype: float64

# %% [markdown]
# #4. List the top 10 companies based on average rating and number of reviews.

# %%
Sort_companies=df.groupby('company').agg({'rating':'mean','reviews':'sum'}).sort_values(by=['rating','reviews'],ascending=False)
# print top 10 companies
Sort_companies.head(10)
# Out:
#                                           rating  reviews
# company
# grass roots research & creation              5.0    884.0
# s&p global inc.                              5.0    207.0
# tekpillar services private limited           5.0    204.0
# srivango                                     5.0    110.0
# gitarattan interantional business school     5.0     90.0
# sone india group of industries               5.0     54.0
# ca one tech                                  5.0     50.0
# ceebros                                      5.0     50.0
# appwrk                                       5.0     44.0
# buyersroad                                   5.0     44.0

# %% [markdown]
# # **Identify Common Job Roles**

# %% [markdown]
# #5. Calculate the frequency of each job role.

# %%
job_role_frequency = df['job_role'].value_counts()
job_role_frequency.head()
# Out:
# job_role
# business development executive    310
# sales executive                   278
# java developer                    267
# business development manager      251
# sales manager                     160
# Name: count, dtype: int64

# %% [markdown]
# #6. Identify the top 10 most common job roles.

# %%
Sort_Job_Role=df.groupby('job_role')['job_role'].count().sort_values(ascending=False)
# print top 10 common job roles.
Sort_Job_Role.head(10)
# Out:
# job_role
# business development executive    310
# sales executive                   278
# java developer                    267
# business development manager      251
# sales manager                     160
# graphic designer                  148
# senior software engineer          147
# dot net developer                 144
# business analyst                  139
# php developer                     139
# Name: job_role, dtype: int64

# %% [markdown]
# # **Analyze Distribution Across Industries**

# %%
df.head(2)
# Out:
#         job_id                                       job_role    company  \
# 0  70123006070  branch banking - calling for women candidates  hdfc bank
# 1  60123905908                   product owner senior manager  accenture
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
#
#                                             location  rating  reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110.0
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
#
#                                      resposibilities  posted_on  \
# 0     customer service,sales,relationship management  1 day ago
# 1  product management,market analysis,change mana...  1 day ago
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
#                                         company_link  min_experience  \
# ...

# %% [markdown]
# #7. Categorize job roles by Company.

# %%
job_categorize=df.groupby('company')['job_role'].unique().reset_index()
job_categorize.head(10)
# Out:
#                                      company  \
# 0                       (v)wecare technology
# 1                                          .
# 2                           0xblock  0xblock
# 3  102/108 ambulance services, uttar pradesh
# 4                                  10xgrowth
# 5          13squad consulting services (opc)
# 6                       18 steps consultants
# 7                              18th digitech
# 8                                        1mg
# 9                                    1point1
#
#                                             job_role
# 0                              [linux administrator]
# 1                                       [3d blender]
# 2  [hiring for qa automation developer, hiring fo...
# 3  [urgent hiring_quality inspector(workshop)_emr...
# 4  [business intelligence lead, php developer, se...
# 5                                    [sales officer]
# 6  [project manager, hr manager - recruitment and...
# ...

# %% [markdown]
# #8. Analyze the frequency of job roles count within each Company.

# %%
job_role_count=df.groupby('company')['job_role'].value_counts().reset_index(name='Number_of_job_Count')
job_role_count.head()
# Out:
#                                      company  \
# 0                       (v)wecare technology
# 1                                          .
# 2                           0xblock  0xblock
# 3                           0xblock  0xblock
# 4  102/108 ambulance services, uttar pradesh
#
#                                             job_role  Number_of_job_Count
# 0                                linux administrator                    1
# 1                                         3d blender                    1
# 2                       hiring for angular developer                    1
# 3                 hiring for qa automation developer                    1
# 4  urgent hiring_quality inspector(workshop)_emri...                    1

# %% [markdown]
# # **Trends in Job Postings Over Time**

# %% [markdown]
# #9. Analyze the number of job postings by date.

# %%
Number_of_job=df.groupby('posted_on')['job_id'].count().reset_index(name='Number_of_Jobs')
Number_of_job.head(10)
# Out:
#      posted_on  Number_of_Jobs
# 0    1 day ago           10915
# 1  10 days ago            3937
# 2   2 days ago            8387
# 3   3 days ago            9317
# 4   4 days ago            8585
# 5   5 days ago            7578
# 6   6 days ago            7790
# 7   7 days ago            1233
# 8   8 days ago            6127
# 9   9 days ago            7429

# %% [markdown]
# # **Location-Specific Job Trends**

# %% [markdown]
# #10. Analyze the number of job postings in different locations.

# %%
Job_location=df.groupby('location')['posted_on'].count().reset_index(name='Number_of_job')
Job_location.head(10)
# Out:
#                                             location  Number_of_job
# 0                                               aalo              1
# 1                                             abohar              1
# 2                                           adilabad              2
# 3                                 adityapur/gamharia              1
# 4                                              adoor              1
# 5                                           agartala             35
# 6                        agartala, barbil, berhampur              2
# 7  agartala, bhagalpur, muzaffarpur, patna, sahar...              1
# 8                                  agartala, kolkata              1
# 9  agartala, kolkata, cuttack, shillong, rourkela...              2

# %% [markdown]
# #11. Identify locations with the highest and lowest number of job postings.

# %% [markdown]
# # Highest Job Location

# %%
Hihgest_location=Job_location.loc[Job_location['Number_of_job'].idxmax()]
Hihgest_location
# Out:
# location         bangalore/bengaluru
# Number_of_job                   9926
# Name: 387, dtype: object

# %% [markdown]
# # Lowest Job Location

# %%
lowest_Job_post=Job_location.loc[Job_location['Number_of_job'].idxmin()]
lowest_Job_post
# Out:
# location         aalo
# Number_of_job       1
# Name: 0, dtype: object

# %% [markdown]
# # **Experience and Salary Analysis**

# %% [markdown]
# #12. Identify the most 10 common experience ranges across job roles.

# %%
experience_range=df.groupby('job_role')['experience'].value_counts().reset_index(name='Number_of_job')
experience_range.head(10)
# Out:
#                                             job_role experience  Number_of_job
# 0                                    . net developer    2-3 yrs              1
# 1             . net developer  (products)\n -gurgaon    2-7 yrs              1
# 2  . net with angular developer (full stack devel...    2-4 yrs              1
# 3                          . pre sales crm day shift    1-5 yrs              2
# 4  . quality analyst international- us shift" -gu...    1-3 yrs              1
# 5                         . tele sales crm day shift    1-5 yrs              1
# 6                                               .net   8-13 yrs              1
# 7                          .net ( dot net) developer    2-6 yrs              1
# 8                         .net (azure) opportunities    3-6 yrs              1
# 9     .net - tech lead / technical architect , noida   7-12 yrs              1

# %% [markdown]
# #13. Identify the most common minimum salary ranges for different job roles and experience levels.

# %%
min_salary_range=df.groupby(['job_role','experience'])['min_salary'].value_counts().reset_index(name='Number_of_jobs')
min_salary_range.head()
# Out:
#                                             job_role experience  min_salary  \
# 0                                    . net developer    2-3 yrs    100000.0
# 1             . net developer  (products)\n -gurgaon    2-7 yrs    500000.0
# 2  . net with angular developer (full stack devel...    2-4 yrs    500000.0
# 3                          . pre sales crm day shift    1-5 yrs    200000.0
# 4  . quality analyst international- us shift" -gu...    1-3 yrs    300000.0
#
#    Number_of_jobs
# 0               1
# 1               1
# 2               1
# 3               2
# 4               1

# %% [markdown]
# #14. Identify the most common maximum salary ranges for different job roles and experience levels.

# %%
max_salary_range=df.groupby(['job_role','experience'])['max_salary'].value_counts().reset_index(name='Number_of_jobs')
max_salary_range.head()
# Out:
#                                             job_role experience  max_salary  \
# 0                                    . net developer    2-3 yrs    450000.0
# 1             . net developer  (products)\n -gurgaon    2-7 yrs   1200000.0
# 2  . net with angular developer (full stack devel...    2-4 yrs   1000000.0
# 3                          . pre sales crm day shift    1-5 yrs    300000.0
# 4  . quality analyst international- us shift" -gu...    1-3 yrs    500000.0
#
#    Number_of_jobs
# 0               1
# 1               1
# 2               1
# 3               2
# 4               1

# %% [markdown]
# #15. Compare salary ranges across various industries and locations.

# %%
salary_range=df.groupby(['company','location'])['salary'].value_counts().reset_index(name='Number_of_Job')
salary_range.head()
# Out:
#                                      company                location  \
# 0                       (v)wecare technology                   noida
# 1                                          .  hyderabad/secunderabad
# 2                           0xblock  0xblock        permanent remote
# 3                           0xblock  0xblock        permanent remote
# 4  102/108 ambulance services, uttar pradesh           uttar pradesh
#
#                      salary  Number_of_Job
# 0   4,00,000 - 8,00,000 pa.              1
# 1             not disclosed              1
# 2  5,00,000 - 12,00,000 pa.              1
# 3             not disclosed              1
# 4             not disclosed              1

# %% [markdown]
# #16. Analyze the correlation between experience levels and salary ranges.

# %%
# df['Average_Salary'] = (df['min_salary'] + df['max_salary']) / 2
# correlation = df['experience'].corr(df['salary'])

# %% [markdown]
# # Now Visualizations Section

# %%
# Firstly Import matplotlib or Seborn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Company_based***
# 1. Top 10 Most Frequently Used Key Skills
# 2. Count of Top Categories in role
# 3. Top 10 Maximum Salary by company Type
# 4. Top 10 Minimum Salary by company Type
# 5. Calculate number of job postings by company
# ***Rating_based***
# 6. Calculate average rating by company
# ***JOB_ROLE***
# 7. Get top 10 unique job roles by average salary
# 8. Plotting Top 10 Job Postings by Job Role
# 9. Plotting Top 10 Average Rating by Job Role
# ***Salary_based***
# 10. Heatmap: Role vs Location
# 11. corelation between (Max_Salary',min_salary, 'Min_Experience', 'Max_Experience')
# 7.top 10 job role
# ***Experience_based***
# 12. Calculate average salary by experience level
# 13. Calculate number of job postings by experience level
# 14. Calculate average rating by experience level

# %% [markdown]
# # Plotting Average minimum Salary by Job Role

# %%
# Calculate average salary by job role
min_avg_salary = df.groupby('job_role')['min_salary'].mean().sort_values()

# %%
min_avg_salary=min_avg_salary.head(10)

# %%
min_avg_salary.plot(kind='barh',color='skyblue')
plt.title('Average salary by job role')
plt.xlabel('job role')
plt.ylabel('Average salary')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Plotting Average Maximun Salary by Job Role

# %%
max_avg_salary=df.groupby('job_role')['max_salary'].mean().sort_values()
max_avg_salary=max_avg_salary.head(10)

# %%
max_avg_salary.plot(kind='bar',color='green')
plt.title('Average salary by job role')
plt.xlabel('job role')
plt.ylabel('Average salary')
plt.xticks(rotation=90)
plt.show()

# %%
df.head(2)
# Out:
#         job_id                                       job_role    company  \
# 0  70123006070  branch banking - calling for women candidates  hdfc bank
# 1  60123905908                   product owner senior manager  accenture
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
#
#                                             location  rating  reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110.0
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
#
#                                      resposibilities  posted_on  \
# 0     customer service,sales,relationship management  1 day ago
# 1  product management,market analysis,change mana...  1 day ago
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
#                                         company_link  min_experience  \
# ...

# %% [markdown]
# # **Top 10 Most Frequently Used Key job role**

# %%
job_role_Frequently=df['job_role'].value_counts
job_role_Frequently=job_role_frequency.head(10)

# %%
# job_role_Frequently

# %%
plt.figure(figsize=(6, 6))
plt.pie(job_role_Frequently, labels=job_role_Frequently.index, autopct='%1.1f%%')
plt.title('Top 10 most Frequently used key job role')
plt.show()

# %% [markdown]
# # **Company Insight's**

# %% [markdown]
# # **Top 10 Maximum Salary by Company Type**

# %%
# Group by industry and find the maximum salary in each industry
max_salary_by_company = df.groupby('company')['max_salary'].max()

# Get the top 10 industries with the highest maximum salaries
top_10_max_salaries = max_salary_by_company.head(10)

# Plotting Top 10 Maximum Salaries by Industry Type
plt.figure(figsize=(8, 6))
top_10_max_salaries.plot(kind='bar', color='orange')
plt.title('Top 10 Maximum Salaries by company Type')
plt.xlabel('company Type')
plt.ylabel('Maximum Salary')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # **Top 10 minimum Salary by Company Type**

# %%
min_salary_by_company=df.groupby('company')['min_salary'].min()
min_salary_by_company=min_salary_by_company.head(10)

plt.figure(figsize=(8,6))
min_salary_by_company.plot(kind='bar',color='red')
plt.title('Top 10 minimum Salary by company Type')
plt.xlabel('company')
plt.ylabel('min_salary')
plt.grid(axis='y')
plt.show()

# %%
# df.head(89)

# %% [markdown]
# # **Calculate top 10 number of job postings by company**

# %%
job_posting_by_company=df.groupby('company')['job_id'].count()
job_posting_by_company=job_posting_by_company.head(10)

plt.figure(figsize=(8,6))
job_posting_by_company.plot(kind='barh', color='lightgreen')
plt.title('Number of job posting by company')
plt.xlabel('company')
plt.ylabel('Number of job posting')
# plt.grid(axis='y')
plt.show()

# %% [markdown]
# # **Calculate Top 10 average rating by company**

# %%
# Avg_rating_by_company=df.groupby('company')['rating'].mean()
# Avg_rating_by_company=Avg_rating_by_company.head(10)

# plt.figure(figsize=(8,6))
# Avg_rating_by_company.plot(kind='Box plot', color='lightgreen')
# plt.title('Average rating by company')
# plt.xlabel('company')
# plt.ylabel('Average rating')
# plt.show()

# %% [markdown]
# # Job_Role Insigts

# %% [markdown]
# # **Get top 10 unique job roles by average salary**

# %%
unique_job_role=df['job_role'].unique()
unique_job_role=unique_job_role.head(10)

plt.figure(figsize=(12, 6))
unique_job_role.plot(kind='barh', color='skyblue')
plt.title('Top 10 Unique Job Roles by Average Salary')
plt.xlabel('Job Role')
plt.ylabel('Average Salary (USD)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-b8637c996d5e> in <cell line: 0>()
#       1 unique_job_role=df['job_role'].unique()
# ----> 2 unique_job_role=unique_job_role.head(10)
#       3
#       4 plt.figure(figsize=(12, 6))
#       5 unique_job_role.plot(kind='barh', color='skyblue')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %% [markdown]
# # **Calculate number of job postings by job role**

# %%
job_postings_count = df['job_role'].value_counts()
job_postings_count = job_postings_count.head(10)

# Plotting Top 10 Job Postings by Job Role
plt.figure(figsize=(12, 6))
job_postings_count.plot(kind='bar', color='skyblue')
plt.title('Top 10 Unique Job Roles by Number of Job Postings')
plt.xlabel('Job Role')
plt.ylabel('Number of Postings')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # **Calculate average rating by job role using Scater Plot**

# %%
avg_rating_by_role=df.groupby('job_role')['rating'].mean().sort_values(ascending=False)
avg_rating_by_role=avg_rating_by_role.head(10)

plt.figure(figsize=(12, 6))
plt.scatter(avg_rating_by_role.index, avg_rating_by_role.values, color='blue', alpha=0.7)
plt.title('Average Rating by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # **12. Calculate average salary by experience level using *Box* Plot**

# %%
avg_sal_exp=df.groupby('experience')['max_salary'].mean().sort_index()
avg_sal_exp=avg_sal_exp.head(10)

# Create a boxplot for average salary by experience level
plt.figure(figsize=(12, 6))
sns.boxplot(x='max_experience', y='max_salary',data=df, palette='Set2')
plt.title('Boxplot of Salary by Experience Level')
plt.xlabel('Experience Level (Years)')
plt.ylabel('Salary (USD)')
plt.grid(axis='y')
plt.show()
# Out:
# <ipython-input-101-460dd8020444>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='max_experience', y='max_salary',data=df, palette='Set2')

# %%
df.head(2)
# Out:
#         job_id                                       job_role    company  \
# 0  70123006070  branch banking - calling for women candidates  hdfc bank
# 1  60123905908                   product owner senior manager  accenture
#
#   experience         salary  \
# 0    1-6 yrs  not disclosed
# 1  11-15 yrs  not disclosed
#
#                                             location  rating  reviews  \
# 0  kolkata, hyderabad/secunderabad, pune, ahmedab...     4.0  39110.0
# 1  kolkata, mumbai, hyderabad/secunderabad, pune,...     4.1  32129.0
#
#                                      resposibilities  posted_on  \
# 0     customer service,sales,relationship management  1 day ago
# 1  product management,market analysis,change mana...  1 day ago
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
#                                         company_link  min_experience  \
# ...
